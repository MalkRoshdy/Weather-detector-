# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.4.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown --folder https://drive.google.com/drive/folders/1Vty06vGqxv5itbKY0mRF7kzl31CWr58f
# Out:
# Retrieving folder contents
# Processing file 1TtH17QaNLwW9KueKBoCyjlK2KOyIhgAe idx_test.npy
# Processing file 1VV7bahYg0kh1id-66sZ-qRDaMkZscOpS idx_train.npy
# Processing file 1aAQzCSKLQv5VNfujitBHgn_8sfcS0EqC idx_val.npy
# Processing file 1KOnyTu37BHk2gF1D8hVHBU98bO40r6Fc label_classes.json
# Processing file 1XI-ZB6EwTEwaLUbdDPo8VchgyCRa8EVQ tfidf_vectorizer.pkl
# Processing file 14LemUrxC6wUUDJhdQIcVhdPZ47DRiUKh tokenizer.pkl
# Processing file 1up21pScT3ekqE3FqJMiFQOmYTBE5srWw X_img_test.npy
# Processing file 1IF_u-PMusYCYhvondn7uXboy_ovSPL9Z X_img_train.npy
# Processing file 12yyA4eTACH9BXrEOY-LL4_E9eKYy5kJK X_img_val.npy
# Processing file 1m5zCCnsOOimjG-RGpDn3cJqRNlvHmI8l X_txt_seq_test.npy
# Processing file 1Gw3Lmo-UVTrB6eG2Zooyy6t0VlUipV5K X_txt_seq_train.npy
# Processing file 1w9wsbl21YJCNzxUWxfFvzpDFaIGn1X4w X_txt_seq_val.npy
# Processing file 1wldEAH8FWFDaBE-eZ-TxH-O8Qoz9hP6x X_txt_tfidf_test.npy
# Processing file 1S8JTmp-LLVJ3euYjEeW9rrumNmqInGqg X_txt_tfidf_train.npy
# Processing file 1etND5q4N_FQA0Samp3YpPZ4KESCXw8Rj X_txt_tfidf_val.npy
# Processing file 1I9WShlfb7P834kHJ2f1t7Zthvk-WEe2u y_test.npy
# Processing file 1KaGWg6lcV4M4-gtdzU2GEKBDSIjzMNL9 y_train.npy
# Processing file 1Xi4QV3Ap8KYLEfMF22RozSNay8qLNZDG y_val.npy
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1TtH17QaNLwW9KueKBoCyjlK2KOyIhgAe
# To: /content/final_data/idx_test.npy
# 100% 768/768 [00:00<00:00, 3.78MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1VV7bahYg0kh1id-66sZ-qRDaMkZscOpS
# To: /content/final_data/idx_train.npy
# 100% 5.22k/5.22k [00:00<00:00, 19.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1aAQzCSKLQv5VNfujitBHgn_8sfcS0EqC
# To: /content/final_data/idx_val.npy
# 100% 768/768 [00:00<00:00, 3.72MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KOnyTu37BHk2gF1D8hVHBU98bO40r6Fc
# To: /content/final_data/label_classes.json
# 100% 109/109 [00:00<00:00, 426kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1XI-ZB6EwTEwaLUbdDPo8VchgyCRa8EVQ
# To: /content/final_data/tfidf_vectorizer.pkl
# 100% 13.7k/13.7k [00:00<00:00, 43.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=14LemUrxC6wUUDJhdQIcVhdPZ47DRiUKh
# To: /content/final_data/tokenizer.pkl
# 100% 12.9k/12.9k [00:00<00:00, 32.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1up21pScT3ekqE3FqJMiFQOmYTBE5srWw
# To: /content/final_data/X_img_test.npy
# 100% 48.2M/48.2M [00:00<00:00, 65.2MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1IF_u-PMusYCYhvondn7uXboy_ovSPL9Z
# From (redirected): https://drive.google.com/uc?id=1IF_u-PMusYCYhvondn7uXboy_ovSPL9Z&confirm=t&uuid=32784187-f34f-4ce5-89d2-ddb48357759d
# To: /content/final_data/X_img_train.npy
# 100% 384M/384M [00:03<00:00, 98.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12yyA4eTACH9BXrEOY-LL4_E9eKYy5kJK
# To: /content/final_data/X_img_val.npy
# 100% 48.2M/48.2M [00:00<00:00, 132MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1m5zCCnsOOimjG-RGpDn3cJqRNlvHmI8l
# To: /content/final_data/X_txt_seq_test.npy
# 100% 32.1k/32.1k [00:00<00:00, 12.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Gw3Lmo-UVTrB6eG2Zooyy6t0VlUipV5K
# To: /content/final_data/X_txt_seq_train.npy
# 100% 255k/255k [00:00<00:00, 84.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1w9wsbl21YJCNzxUWxfFvzpDFaIGn1X4w
# To: /content/final_data/X_txt_seq_val.npy
# 100% 32.1k/32.1k [00:00<00:00, 56.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1wldEAH8FWFDaBE-eZ-TxH-O8Qoz9hP6x
# To: /content/final_data/X_txt_tfidf_test.npy
# 100% 234k/234k [00:00<00:00, 118MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1S8JTmp-LLVJ3euYjEeW9rrumNmqInGqg
# To: /content/final_data/X_txt_tfidf_train.npy
# 100% 1.86M/1.86M [00:00<00:00, 97.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1etND5q4N_FQA0Samp3YpPZ4KESCXw8Rj
# To: /content/final_data/X_txt_tfidf_val.npy
# 100% 234k/234k [00:00<00:00, 97.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1I9WShlfb7P834kHJ2f1t7Zthvk-WEe2u
# To: /content/final_data/y_test.npy
# 100% 768/768 [00:00<00:00, 3.22MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KaGWg6lcV4M4-gtdzU2GEKBDSIjzMNL9
# To: /content/final_data/y_train.npy
# 100% 5.22k/5.22k [00:00<00:00, 19.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Xi4QV3Ap8KYLEfMF22RozSNay8qLNZDG
# To: /content/final_data/y_val.npy
# 100% 768/768 [00:00<00:00, 3.80MB/s]
# Download completed

# %%
import numpy as np

X_train = np.load('/content/final_data/X_txt_tfidf_train.npy')
X_test = np.load('/content/final_data/X_txt_tfidf_test.npy')
X_val = np.load('/content/final_data/X_txt_tfidf_val.npy')

y_train = np.load('/content/final_data/y_train.npy')
y_test = np.load('/content/final_data/y_test.npy')
y_val = np.load('/content/final_data/y_val.npy')

print(X_train.shape)
print(y_train.shape)
# Out:
# (637, 365)
# (637,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

print(X_train.shape)
# Out:
# (637, 365, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

model = Sequential()

# CNN
model.add(Conv1D(
    filters=128,
    kernel_size=3,
    activation='relu',
    input_shape=(365,1)
))

model.add(MaxPooling1D(pool_size=2))

model.add(Flatten())

# ANN
model.add(Dense(128, activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))

# Output
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 363, 128)       │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 181, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 23168)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,965,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,974,465 (11.35 MB)
#  Trainable params: 2,974,465 (11.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(np.unique(y_train))
# Out:
# [0 1 2 3 4 5]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.layers import Flatten, Dense, Dropout

model = Sequential()

# CNN
model.add(Conv1D(
    128,
    3,
    activation='relu',
    input_shape=(365,1)
))

model.add(MaxPooling1D(2))

model.add(Flatten())

# ANN
model.add(Dense(128, activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))

# Output for 6 classes
model.add(Dense(6, activation='softmax'))

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)               │ (None, 363, 128)       │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 181, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 23168)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │     2,965,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,974,790 (11.35 MB)
#  Trainable params: 2,974,790 (11.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.8571 - loss: 1.0876 - val_accuracy: 1.0000 - val_loss: 0.1646
# Epoch 2/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.1124 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 3/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 1.0000 - val_loss: 5.0566e-04
# Epoch 4/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 2.0844e-04
# Epoch 5/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 1.1547e-04
# Epoch 6/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 8.0147e-05
# Epoch 7/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 5.3453e-05
# Epoch 8/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 4.5633e-05
# Epoch 9/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 4.5099e-05
# Epoch 10/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 2.0270e-05

# %%
from sklearn.metrics import f1_score

pred = model.predict(X_test)

pred = pred.argmax(axis=1)

f1 = f1_score(y_test, pred, average='weighted')

print("F1 Score:", f1)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 301ms/step
# F1 Score: 1.0

# %%
import json

with open('/content/final_data/label_classes.json', 'r') as f:
    labels = json.load(f)

print(labels)
# Out:
# {'0': 'amoxicillin', '1': 'aspirin', '2': 'ibuprofen', '3': 'insulin', '4': 'omeprazole', '5': 'paracetamol'}

# %%
# !gdown https://drive.google.com/uc?id=1cD_KoHbUXe0MkHySgnSfnR0epdYmOXMO
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cD_KoHbUXe0MkHySgnSfnR0epdYmOXMO
# To: /content/safety_dataset.json
# 100% 3.36k/3.36k [00:00<00:00, 11.2MB/s]

# %%
# !gdown https://drive.google.com/uc?id=1q5Co2P4kHM6rt7eGfYxVnFxkbkTJqKmM
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1q5Co2P4kHM6rt7eGfYxVnFxkbkTJqKmM
# To: /content/interaction_dataset.json
# 100% 764/764 [00:00<00:00, 3.34MB/s]

# %%
with open('/content/safety_dataset.json', 'r') as f:
    safety_data = json.load(f)

print(safety_data)
# Out:
# [{'input': 'drug: paracetamol; condition: pregnancy', 'output': 'safety: safe; recommendation: commonly used; alternative: none'}, {'input': 'drug: paracetamol; condition: liver disease', 'output': 'safety: warning; recommendation: use low dose; alternative: consult doctor'}, {'input': 'drug: paracetamol; condition: fever', 'output': 'safety: safe; recommendation: reduces temperature; alternative: ibuprofen'}, {'input': 'drug: paracetamol; condition: headache', 'output': 'safety: safe; recommendation: effective for headache; alternative: ibuprofen'}, {'input': 'drug: paracetamol; condition: pain', 'output': 'safety: safe; recommendation: general pain relief; alternative: ibuprofen'}, {'input': 'drug: ibuprofen; condition: high blood pressure', 'output': 'safety: warning; recommendation: avoid long-term use; alternative: paracetamol'}, {'input': 'drug: ibuprofen; condition: low blood pressure', 'output': 'safety: warning; recommendation: use carefully; alternative: consult doctor'}, {'input': 'drug: ibuprofen; condition: stomach ulcer', 'output': 'safety: dangerous; recommendation: do not use; alternative: paracetamol'}, {'input': 'drug: ibuprofen; condition: fever', 'output': 'safety: safe; recommendation: reduces fever; alternative: paracetamol'}, {'input': 'drug: ibuprofen; condition: headache', 'output': 'safety: safe; recommendation: strong pain relief; alternative: paracetamol'}, {'input': 'drug: ibuprofen; condition: pain', 'output': 'safety: safe; recommendation: effective pain relief; alternative: paracetamol'}, {'input': 'drug: aspirin; condition: stomach ulcer', 'output': 'safety: dangerous; recommendation: avoid completely; alternative: paracetamol'}, {'input': 'drug: aspirin; condition: normal', 'output': 'safety: safe; recommendation: use with food; alternative: none'}, {'input': 'drug: aspirin; condition: headache', 'output': 'safety: safe; recommendation: pain relief; alternative: paracetamol'}, {'input': 'drug: aspirin; condition: pain', 'output': 'safety: safe; recommendation: mild pain relief; alternative: paracetamol'}, {'input': 'drug: amoxicillin; condition: normal', 'output': 'safety: safe; recommendation: follow prescription; alternative: none'}, {'input': 'drug: amoxicillin; condition: allergy', 'output': 'safety: dangerous; recommendation: do not use; alternative: consult doctor'}, {'input': 'drug: amoxicillin; condition: cough', 'output': 'safety: warning; recommendation: use only if bacterial infection; alternative: consult doctor'}, {'input': 'drug: insulin; condition: diabetes', 'output': 'safety: safe; recommendation: necessary medication; alternative: none'}, {'input': 'drug: insulin; condition: low blood sugar', 'output': 'safety: dangerous; recommendation: avoid; alternative: adjust dosage'}, {'input': 'drug: omeprazole; condition: acid reflux', 'output': 'safety: safe; recommendation: effective; alternative: none'}, {'input': 'drug: omeprazole; condition: long term use', 'output': 'safety: warning; recommendation: monitor usage; alternative: consult doctor'}]

# %%
drug_name = "paracetamol"

for item in safety_data:

    if drug_name in item['input']:

        print(item['output'])
# Out:
# safety: safe; recommendation: commonly used; alternative: none
# safety: warning; recommendation: use low dose; alternative: consult doctor
# safety: safe; recommendation: reduces temperature; alternative: ibuprofen
# safety: safe; recommendation: effective for headache; alternative: ibuprofen
# safety: safe; recommendation: general pain relief; alternative: ibuprofen
